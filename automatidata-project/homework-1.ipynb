# %% [markdown]
# # Homework 6: Automatidata

# %%
#Import pandas library
import pandas as pd

# %%
# Load Automatidata dataset (2017 Yellow Taxi Trip data) into dataframe
taxi_df = pd.read_csv("2017_Yellow_Taxi_Trip_Data.csv")

# %%
# By applying method, show first 7 rows in dataframe
taxi_df.head(7)
# Out:
#       TripID  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0   24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1   35634249         1        04/11/2017 14:53        04/11/2017 15:19
# 2  106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3   38942136         2        05/07/2017 13:17        05/07/2017 13:48
# 4   30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# 5   23345809         2   03/25/2017 8:34:11 PM   03/25/2017 8:42:11 PM
# 6   37660487         2        05/03/2017 19:04        05/03/2017 20:03
#
#    passenger_count  trip_distance  PULocationID  DOLocationID  RatecodeID  \
# 0                6           3.34           100           231           1
# 1                1           1.80           186            43           1
# 2                1           1.00           262           236           1
# 3                1           3.70           188            97           1
# ...

# %%
# By applying method, show summary information about the dataframe
taxi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   TripID                 22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   PULocationID           22699 non-null  int64
#  7   DOLocationID           22699 non-null  int64
#  8   RatecodeID             22699 non-null  int64
#  9   store_and_fwd_flag     22699 non-null  object
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
# By applying attribute, check the list of column labels in dataframe
taxi_df.columns
# Out:
# Index(['TripID', 'VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'PULocationID', 'DOLocationID',
#        'RatecodeID', 'store_and_fwd_flag', 'payment_type', 'fare_amount',
#        'extra', 'mta_tax', 'improvement_surcharge', 'tip_amount',
#        'tolls_amount', 'total_amount'],
#       dtype='object')

# %%
# By applying attribute, show tuple representing dimensionality
# (number of rows and columns) of the dataframe
taxi_df.shape
# Out:
# (22699, 18)

# %%
# By applying attribute, show from 1st to 3rd rows
# You can use either iloc or loc
taxi_df.iloc[0:3]
# Out:
#       TripID  VendorID   tpep_pickup_datetime  tpep_dropoff_datetime  \
# 0   24870114         2  03/25/2017 8:55:43 AM  03/25/2017 9:09:47 AM
# 1   35634249         1       04/11/2017 14:53       04/11/2017 15:19
# 2  106203690         1  12/15/2017 7:26:56 AM  12/15/2017 7:34:08 AM
#
#    passenger_count  trip_distance  PULocationID  DOLocationID  RatecodeID  \
# 0                6           3.34           100           231           1
# 1                1           1.80           186            43           1
# 2                1           1.00           262           236           1
#
#   store_and_fwd_flag  payment_type  fare_amount  extra  mta_tax  \
# 0                  N             1         13.0    0.0      0.5
# 1                  N             1         16.0    0.0      0.5
# 2                  N             1          6.5    0.0      0.5
#
#    improvement_surcharge  tip_amount  tolls_amount  total_amount
# ...

# %%
# Show 'TripId', 'trip_distance', and 'fare_amount' of 100th to 103th row
# You can use either iloc or loc
taxi_df.iloc[99:103, [0, 5, 11]]
# Out:
#        TripID  trip_distance  fare_amount
# 99   22572601           1.42          7.0
# 100  11538055           0.72          8.0
# 101  26548374           9.67         31.0
# 102  44715204           2.30         12.5

# %%
# Show the total_amount of 12000th row
# You can use either iloc or loc
taxi_df.loc[11999, 'total_amount']
# Out:
# 12.8

# %%
# Add a new column 'percent_tip' which is computed by: (tip_amount/total_amount)*100 to dataframe
# to show the percentage of tip paid realtive to total amount.
# Then show first 5 rows of dataframe.
taxi_df['percent_tip'] = (taxi_df['tip_amount'] / taxi_df['total_amount']) * 100
taxi_df.head()
# Out:
#       TripID  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0   24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1   35634249         1        04/11/2017 14:53        04/11/2017 15:19
# 2  106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3   38942136         2        05/07/2017 13:17        05/07/2017 13:48
# 4   30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#    passenger_count  trip_distance  PULocationID  DOLocationID  RatecodeID  \
# 0                6           3.34           100           231           1
# 1                1           1.80           186            43           1
# 2                1           1.00           262           236           1
# 3                1           3.70           188            97           1
# 4                1           4.37             4           112           1
#
#   store_and_fwd_flag  payment_type  fare_amount  extra  mta_tax  \
# ...
